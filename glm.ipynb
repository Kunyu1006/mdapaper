# %%
import requests

api_key = ""  # 替换成你在智谱清言上生成的API Key

url = "https://open.bigmodel.cn/api/paas/v4/chat/completions"

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}

# 示例MDA文本（可以替换成你的一段真实数据）
input_text = """
第三节管理层讨论与分析

一、报告期内公司所处的行业情况

2021年是我国医药行业改革不断深化，行业政策密集出台，创新成果不断涌现，行业洗牌持续加速的一年。医保控费仍是医药行业政策的主旋律。2021年国家持续推进药品和耗材集中采购，集采广度和深度都在进一步拓展。仿制药与高值医用耗材带量集采趋于常态化，未来预计将继续扩大品种和地区范围。地方集采层面，区域性跨区的联盟集采节奏加快，采购品种更多样灵活，省际联盟已成为带量采购的另一支主力军。
医保支付方式改革加快推进。国家医保局正在推行以按病种付费为主的多元复合式医保支付方式，推广按疾病诊断相关分组（DRG）付费和按病种分值付费（DIP）试点。2021年11月国家医保局发布《DRG/DIP支付方式改革三年行动计划》，要求到2025年底，DRG/DIP支付方式覆盖所有符合条件的开展住院服务的医疗机构，基本实现病种、医保基金全覆盖。从行业长期发展趋势来看，我国老龄化加剧刚需医药市场扩容，健康消费升级进一步提
升消费医药渗透率，行业增长机遇不断释放。医药行业在一系列政策的驱动下，正进行深刻的变革，行业将加速向创新方向转型。医药企业的增长逻辑和成长前景也在发生巨大变化，越来越多传统药企明确了转型创新药的方向，并不断加大研发投入，力促企业实现高质量发展。
2022年是“十四五”时期的改革深化之年，医药工业行业“十四五”发展规划将颁布并实施，医药行业创新迭代周期将更快，医药企业面临的挑战和压力也将更大。在新医改持续深化、产业技术加速迭代、专业人才不断涌现、资本支持日益加强的当前，中国医药企业面对机遇与挑战犹如逆水行舟，唯有升级创新，方可乘风破浪。

二、报告期内公司从事的主要业务

华东医药股份有限公司（证券代码：000963）创建于1993年，总部位于浙江杭州，于1999年12月在深圳证券交易所上市。历经20余年的发展，公司业务覆盖医药全产业链，以医药工业为主导，同时拓展医药商业和医美产业，已发展成为集医药研发、生产、经销为一体的大型综合性医药上市公司。
公司医药工业深耕于专科、慢病用药及特殊用药领域的研发、生产和销售，已形成完备的医药生产制造和质量研究体系，并形成以慢性肾病、移植免疫、内分泌、消化系统等领域
为主的核心产品管线，拥有多个在国内具有市场优势的一线临床用药，同时通过自主开发、外部引进、项目合作等方式重点在肿瘤、内分泌和自身免疫三大核心治疗领域的创新药及高技术壁垒仿制药进行研发布局。公司持续开展产品国际注册、国际认证、一致性评价等工作，并持续取得成果，已形成面向国际的制药工业体系，与多家国际创新研发企业保持研发及产品合作关系。
公司医药商业拥有中西药、医疗器械、药材参茸、健康产业四大业务板块，涵盖医药批发、医药零售、以冷链为特色的第三方医药物流、医药电商、医院增值服务及特色大健康产业，进一步开拓产品代理与市场拓展领域，为客户提供综合性解决方案。
"""

prompt = f"""
以下是某公司年报中的管理层讨论与分析内容：

{input_text}

请你删除其中冗余性强的空话、套话，并提取出与公司治理相关的重要信息，以结构化的条目形式列出，如：
【董事会成员变动】：
- 【董秘变更】：
- 【高级管理层变更】：
- 【重大资产重组】：
- 【对公司治理的讨论】：
- 【对财务状况的分析】：
- 【行业趋势分析】：
- 【核心竞争力分析】：
- 【未来经营计划】：
"""

data = {
    "model": "glm-4",
    "messages": [
        {"role": "user", "content": prompt}
    ],
    "temperature": 0.3,
    "max_tokens": 1024
}

response = requests.post(url, headers=headers, json=data)

result = response.json()
print("提取结果：\n")
print(result['choices'][0]['message']['content'])
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\C'
# <>:13: SyntaxWarning: invalid escape sequence '\C'
# /var/folders/j7/xs82g81n7nj2_8x4_fgcmfsr0000gn/T/ipykernel_42174/3189297423.py:13: SyntaxWarning: invalid escape sequence '\C'
#   input_text = """
# 提取结果：
#
# 【董事会成员变动】：
# - 无
#
# 【董秘变更】：
# - 无
#
# 【高级管理层变更】：
# - 无
#
# 【重大资产重组】：
# - 公司收购浙江道尔生物科技有限公司75%股权，成为其控股股东。
# - 公司收购西班牙能量源型医美器械公司HighTechnologyProducts,S.L.U.100%股权。
# - 公司收购安徽华昌高科药业有限公司100%股权。
#
# 【对公司治理的讨论】：
# - 公司加强管理创新，提升经营质量，满足市场竞争需求。
# - 公司完善架构布局，深化研发体系组织架构改革，提升研发效率。
# - 公司启动高潜人才培养项目，完善分层分级人才培养体系。
#
# 【对财务状况的分析】：
# - 2021年公司实现营业收入345.63亿元，同比增长2.61%。
# - 2021年公司实现净利润23.02亿元，同比下降18.38%。
# - 2021年公司经营活动产生的现金流量净额为31.7亿元。
#
# 【行业趋势分析】：
# - 医药行业改革深化，政策密集出台，创新成果涌现，行业洗牌加速。
# - 医保控费仍是政策主旋律，药品和耗材集中采购常态化。
# - 医保支付方式改革加快推进，按病种付费成为主要支付方式。
#
# 【核心竞争力分析】：
# - 公司拥有开放的创新药研发体系，持续提升的创新能力。
# - 公司具有全面的国际化业务开拓能力。
# - 公司拥有丰富的专科慢病产品管线及糖尿病治疗领域综合竞争优势。
# - 公司拥有国内领先的药学服务专业化团队及广泛的市场网络。
#
# 【未来经营计划】：
# - 公司将继续推进创新转型，加速创新药研发。
# ...

# %%
import requests

api_key = ""  # 替换成你在智谱清言上生成的API Key

url = "https://open.bigmodel.cn/api/paas/v4/chat/completions"

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}

# 示例MDA文本（可以替换成你的一段真实数据）
input_text = """
第四节 董事会报告

一、概述
概述：面对行业利润摊薄、市场分化的严峻形势，报告期内较好地完成工作任务。
经营环境变化：房地产业迎来了自2008年世界金融危机后难得的“黄金年”。
公司经营与管理情况：两个异地项目公司销售业绩均达到历史最好水平

二、主营业务分析

1、概述

单位：元

公司回顾总结前期披露的发展战略和经营计划在报告期内的进展情况：新开工项目数量、面积和工程进度均取得历史性突破

报告期内公司经营活动的现金流量与本年度净利润存在重大差异的原因说明
□ 适用 √ 不适用

核心竞争力分析：项目开发全面提速、楼盘销售业绩不俗、成本管控体系领先、对标管理工作取得实效


行业竞争格局和发展趋势：中国房地产将告别快速开发，高速增长的“黄金时代”，面临变革、转型。房地产企业需审时度势，立足中部省会和中心城市，将带来难得的发展机会。城市更新是企业高速发 展的新引擎。

2014年公司经营计划和发展战略：
着力抓好项目建设和楼盘销售工作，要努力实现从一个住宅产品制造商向住宅产品运营商角色的转变。二是，稳住阵脚。三是，敢闯敢试。四是，创先争优。

可能面对的风险及应对措施：资产规模小，经营模式单一，土地、资金、人才等资源方面存在隐忧。


"""

prompt = f"""
以下是某公司2013年年报中的“管理层讨论与分析”部分内容，请你遵循以下要求处理该文本：

1. 删除冗余性强的空话、套话。
2. 仅保留具有研究价值的具体内容，尤其是与公司治理和业绩相关的信息。
3. 请**严格按照以下结构模板**输出内容，每个条目都必须出现，即使原文没有相关内容，也请写明“无相关信息”或“未提及”。

【固定输出结构如下】：
- 【董事会成员变动】：
- 【董秘变更】：
- 【高级管理层变更】：
- 【重大资产重组】：
- 【对公司治理的讨论】：
- 【对财务状况的分析】：
- 【行业趋势分析】：
- 【核心竞争力分析】：
- 【未来经营计划】：

请用结构化文本形式输出结果。

原文如下：
{input_text}
"""

data = {
    "model": "glm-4",
    "messages": [
        {"role": "user", "content": prompt}
    ],
    "temperature": 0.3,
    "max_tokens": 1024
}

response = requests.post(url, headers=headers, json=data)

result = response.json()
print("提取结果：\n")
print(result['choices'][0]['message']['content'])
# Out:
# 提取结果：
#
# - 【董事会成员变动】：
#   - 未提及
#
# - 【董秘变更】：
#   - 未提及
#
# - 【高级管理层变更】：
#   - 未提及
#
# - 【重大资产重组】：
#   - 未提及
#
# - 【对公司治理的讨论】：
#   - 无相关信息
#
# - 【对财务状况的分析】：
#   - 报告期内公司经营活动的现金流量与本年度净利润存在重大差异，但未具体说明原因。
#
# - 【行业趋势分析】：
#   - 中国房地产将告别快速开发、高速增长的“黄金时代”，面临变革和转型。企业需审时度势，立足中部省会和中心城市，城市更新成为企业高速发展的新引擎。
#
# - 【核心竞争力分析】：
#   - 项目开发全面提速、楼盘销售业绩不俗、成本管控体系领先、对标管理工作取得实效。
#
# - 【未来经营计划】：
#   - 着力抓好项目建设和楼盘销售工作，实现从住宅产品制造商向住宅产品运营商的转变。稳住阵脚，敢闯敢试，创先争优。同时，意识到可能面对的风险，如资产规模小、经营模式单一、土地、资金、人才等资源方面的隐忧。

# %%
# Out:
# 提取结果：
#
# - 【董事会成员变动】：
#   - 未提及
#
# - 【董秘变更】：
#   - 未提及
#
# - 【高级管理层变更】：
#   - 未提及
#
# - 【重大资产重组】：
#   - 未提及
#
# - 【对公司治理的讨论】：
#   - 无相关信息
#
# - 【对财务状况的分析】：
#   - 两个异地项目公司销售业绩均达到历史最好水平
#
# - 【行业趋势分析】：
#   - 中国房地产将告别快速开发，高速增长的“黄金时代”，面临变革、转型。房地产企业需审时度势，立足中部省会和中心城市，将带来难得的发展机会。城市更新是企业高速发展的新引擎。
#
# - 【核心竞争力分析】：
#   - 项目开发全面提速、楼盘销售业绩不俗、成本管控体系领先、对标管理工作取得实效
#
# - 【未来经营计划】：
#   - 着力抓好项目建设和楼盘销售工作，要努力实现从一个住宅产品制造商向住宅产品运营商角色的转变。稳住阵脚，敢闯敢试，创先争优。
#   - 可能面对的风险及应对措施：资产规模小，经营模式单一，土地、资金、人才等资源方面存在隐忧。
#
# 已保存为 single.csv

# %%
import os
import requests
import pandas as pd
import time

# %%
import requests


API_URL = "https://api.siliconflow.cn/v1/chat/completions"


from dotenv import load_dotenv
load_dotenv()  # 加载.env文件

api_key = os.getenv("API_KEY")
model_name = os.getenv("MODEL_NAME", "Qwen/Qwen3-8B")  # 可设默认值

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

payload = {
    "model": MODEL_NAME,
    "messages": [
        {"role": "user", "content": "请介绍一下Qwen3-8B模型的特点。"}
    ],
    "max_tokens": 512,
    "temperature": 0.7,
    "top_p": 0.9
}

response = requests.post(API_URL, json=payload, headers=headers)

if response.status_code == 200:
    result = response.json()
    print("模型输出：", result["choices"][0]["message"]["content"])
else:
    print("请求失败：", response.status_code, response.text)
# Out:
# 模型输出：
#
# Qwen3-8B 是通义千问系列中一个参数量为 80 亿的模型版本，属于 Qwen3 系列的一部分。它在性能、效率和适用场景上进行了多项优化，以下是其主要特点：
#
# ---
#
# ### **1. 性能与效率的平衡**
# - **参数量**：80 亿参数，相比更小规模的模型（如 Qwen1.8B）在复杂任务中表现更优，同时比更大规模的模型（如 Qwen14B）更节省计算资源。
# - **推理速度**：通过模型结构优化和量化技术，推理速度显著提升，适合对实时性要求较高的场景。
# - **内存占用**：优化后的模型在部署时占用的显存和内存更少，降低了对硬件的要求。
#
# ---
#
# ### **2. 多语言支持**
# - **语言覆盖**：支持多种语言（如中文、英文、日文、韩文等），能够处理跨语言任务，如多语言翻译、跨语言问答等。
# - **本地化能力**：针对不同语言的语料进行优化，确保在非英语任务中的表现接近甚至超越其他主流模型。
#
# ---
#
# ### **3. 强大的代码生成与理解能力**
# - **编程语言支持**：支持多种编程语言（如 Python、Java、JavaScript 等），能够生成高质量代码并解释复杂逻辑。
# - **调试与优化**：可协助分析代码错误、优化性能，并提供代码重构建议。
#
# ---
#
# ### **4. 上下文理解与长文本处理**
# - **长上下文支持**：优化了对长文本的处理能力，适合处理需要连续对话或长文档分析的任务（如法律文件、技术文档等）。
# - **多轮对话**：在对话场景中保持上下文连贯性，减少重复和误解。
#
# ---
#
# ### **5. 多模态与扩展能力**
# - **多模态支持**：部分版本可能集成图像、音频等多模态能力（需确认具体版本是否支持）。
# - **API 接口**：提供灵活的 API 接口，便于集成到各类应用（如客服系统、内容生成平台等）。
#
# ---
#
# ### **6. 适用场景**
# - **企业级应用**：适合需要高性能文本处理的场景，如智能客服、数据分析、内容创作等。
# - **开发者工具**：作为代码生成和调试的

# %%
from dotenv import load_dotenv
import os

load_dotenv("model.env")  # 指定你自己的 .env 文件名

API_KEY = os.getenv("API_KEY")
MODEL_NAME = os.getenv("MODEL_NAME")
# Out:
# sk-vtpefpeaoggdppvaxlhmwmidtsevuryhxfubpsztrnhgvmmn
# Qwen/Qwen3-8B

# %%
import os
import requests
import pandas as pd
import time
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
from dotenv import load_dotenv  # ✅ 加载 .env 所需

# ✅ 加载环境变量（确保你本地有 model.env 文件）
load_dotenv("model.env")  # 指定文件名

# ✅ 从环境变量中获取 API_KEY 和模型名
api_key = os.getenv("API_KEY")
model_name = os.getenv("MODEL_NAME")

if not api_key or not model_name:
    raise ValueError("❌ 缺少 API_KEY 或 MODEL_NAME，请检查 model.env 文件是否设置正确")

url = "https://api.siliconflow.cn/v1/chat/completions"
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}
# ✅ 输入输出路径
input_folder = "/Users/yukun/Desktop/mda/MDA训练集"
output_csv_path = "qw.csv"

# ✅ 提取字段
output_fields = [
    "文件名",
    "董事会成员变动",
    "董秘变更",
    "高级管理层变更",
    "重大资产重组",
    "控股股东/实际控制人变更",
    "子公司或重要分支机构重大变化",
    "对财务状况的分析",
    "营业收入增长情况",
    "净利润变动分析",
    "毛利率变动分析",
    "销售费用率变化",
    "管理费用控制情况",
    "经营性现金流变化趋势",
    "应收账款变化与风险",
    "资产负债结构调整",
    "利润质量分析（是否依赖非经常性损益）",
    "核心竞争力分析（品牌、成本、效率等）",
    "市场拓展与业务布局进展",
    "区域/产品结构优化情况",
    "供应链/渠道建设进展",
    "战略合作与外部联盟情况",
    "投资项目执行及回报分析",
    "企业文化建设与团队稳定性",
    "对标管理与精细化运营成果",
    "技术创新与研发投入",
    "新产品/新技术推出情况",
    "研发费用占比变化",
    "专利数量与知识产权布局",
    "智能制造/数字化转型进展",
    "行业竞争格局分析",
    "行业发展趋势与机会识别",
    "国家政策影响与公司应对",
    "未来经营计划与增长目标",
    "订单/客户/签约情况展望",
    "海外市场/出口业务计划",
    "对经济周期或宏观环境的判断",
    "面临的主要风险因素及变化",
    "政策/监管风险与公司响应",
    "环保合规/碳排放压力",
    "土地/原材料/人工成本波动风险",
    "资金链紧张预警",
    "核心客户集中度及流失风险",
    "可持续发展战略与目标",
    "社会责任履行与公益活动",
    "节能降耗/绿色生产措施"
]

# ✅ Prompt模板
def build_prompt(text):
    return f"""
以下是某公司年报中的“管理层讨论与分析”部分内容，请你遵循以下要求处理该文本：

1. 删除冗余性强的空话、套话。
2. 仅保留具有研究价值的具体内容，尤其是与公司治理和业绩相关的信息。
3. 请严格按照以下结构模板输出内容，每个条目都必须出现，即使原文没有相关内容，也请写明“无相关信息”或“未提及”。

【固定输出结构如下】：
{chr(10).join([f"- 【{field}】：" for field in output_fields[1:]])}

原文如下：
{text}
"""

# ✅ 每个文件的处理函数
def process_file(file_path):
    filename = os.path.basename(file_path)
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            text = f.read()

        prompt = build_prompt(text)
        data = {
            "model": model_name,
            "messages": [{"role": "user", "content": prompt}],
            "temperature": 0.2,
            "max_tokens": 2048
        }

        response = requests.post(url, headers=headers, json=data)
        response.raise_for_status()
        response_data = response.json()

        if "choices" not in response_data:
            raise ValueError("接口返回中未包含choices字段，可能是模型名称错误或token用尽")

        content = response_data["choices"][0]["message"]["content"]
        row = [filename]

        for field in output_fields[1:]:
            key = f"- 【{field}】："
            start = content.find(key)
            if start != -1:
                end = content.find("- 【", start + 1)
                value = content[start + len(key):end].strip() if end != -1 else content[start + len(key):].strip()
            else:
                value = "未提及"
            row.append(value)

        print(f"✔ 完成：{filename}")
        return row

    except Exception as e:
        print(f"✘ 出错：{filename}，错误：{e}")
        return [filename] + ["ERROR"] * (len(output_fields) - 1)

# ✅ 并发运行
def run_parallel():
    file_paths = [
        os.path.join(input_folder, f)
        for f in os.listdir(input_folder)
        if f.endswith(".txt")
    ]

    results = []

    with ThreadPoolExecutor(max_workers=5) as executor:  # 控制并发线程数
        future_to_file = {executor.submit(process_file, file): file for file in file_paths}

        for future in as_completed(future_to_file):
            result = future.result()
            results.append(result)

    df = pd.DataFrame(results, columns=output_fields)
    df.to_csv(output_csv_path, index=False, encoding="utf-8-sig")
    print(f"\n✅ 全部处理完成，结果保存在：{output_csv_path}")

if __name__ == "__main__":
    run_parallel()
# Out:
# ✔ 完成：2429-兆驰股份-2021.txt
# ✔ 完成：600566-济川药业-2021.txt
# ✔ 完成：2552-宝鼎科技-2021.txt
# ✔ 完成：895-双汇发展-2021.txt
# ✔ 完成：2415-海康威视-2021.txt
# ✔ 完成：963-华东医药-2021.txt
# ✔ 完成：2475-立讯精密-2021.txt
# ✔ 完成：2241-歌尔股份-2021.txt
# ✘ 出错：2507-涪陵榨菜-2021.txt，错误：429 Client Error: Too Many Requests for url: https://api.siliconflow.cn/v1/chat/completions
# ✔ 完成：600031-三一重工-2021.txt
# ✘ 出错：2230-科大讯飞-2021.txt，错误：429 Client Error: Too Many Requests for url: https://api.siliconflow.cn/v1/chat/completions
# ✔ 完成：300339-润和软件-2021.txt
# ✔ 完成：600519-贵州茅台-2021.txt
# ✔ 完成：425-徐工机械-2021.txt
# ✔ 完成：600276-恒瑞医药-2021.txt
#
# ✅ 全部处理完成，结果保存在：qw.csv

# %%
test_file = os.path.join(input_folder, os.listdir(input_folder)[0])
with open(test_file, "r", encoding="utf-8") as f:
    text = f.read()
print(text[:500])  # 只打印开头500字符，确认读取无误
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 3
#       1 test_file = os.path.join(input_folder, os.listdir(input_folder)[0])
#       2 with open(test_file, "r", encoding="utf-8") as f:
# ----> 3     text = f.read()
#       4 print(text[:500])  # 只打印开头500字符，确认读取无误
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 3131: invalid start byte

# %%
sample_prompt = build_prompt(text)
print(sample_prompt[:1000])  # 只打印前1000字符，检查格式和字段
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sample_prompt = build_prompt(text)
#       2 print(sample_prompt[:1000])  # 只打印前1000字符，检查格式和字段
#
# NameError: name 'text' is not defined
